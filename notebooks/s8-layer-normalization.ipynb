# %%
# !git clone 'https://github.com/aakashvardhan/s8-normalization.git'
# Out:
# Cloning into 's8-normalization'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 110 (delta 49), reused 82 (delta 21), pack-reused 0
# Receiving objects: 100% (110/110), 1007.62 KiB | 4.99 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
import sys
sys.path.append('/content/s8-normalization')
sys.path.append('/content/s8-normalization/models')

# %%
from config import get_config
config = get_config()
from main import main

# %% [markdown]
# Modify Config File

# %%
config['norm'] = 'ln'

# %%
model, test_loader = main(config)
# Out:
# CUDA Available? True
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49396302.35it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#               ReLU-2           [-1, 32, 32, 32]               0
#          GroupNorm-3           [-1, 32, 32, 32]              64
#            Dropout-4           [-1, 32, 32, 32]               0
#          ConvBlock-5           [-1, 32, 32, 32]               0
#             Conv2d-6           [-1, 32, 32, 32]           9,216
#               ReLU-7           [-1, 32, 32, 32]               0
#          GroupNorm-8           [-1, 32, 32, 32]              64
#            Dropout-9           [-1, 32, 32, 32]               0
#         ConvBlock-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]             512
#         MaxPool2d-12           [-1, 16, 16, 16]               0
#   TransitionBlock-13           [-1, 16, 16, 16]               0
#            Conv2d-14           [-1, 16, 16, 16]           2,304
#              ReLU-15           [-1, 16, 16, 16]               0
#         GroupNorm-16           [-1, 16, 16, 16]              32
#           Dropout-17           [-1, 16, 16, 16]               0
#         ConvBlock-18           [-1, 16, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           4,608
#              ReLU-20           [-1, 32, 16, 16]               0
#         GroupNorm-21           [-1, 32, 16, 16]              64
#           Dropout-22           [-1, 32, 16, 16]               0
#         ConvBlock-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 32, 16, 16]           9,216
#              ReLU-25           [-1, 32, 16, 16]               0
#         GroupNorm-26           [-1, 32, 16, 16]              64
#           Dropout-27           [-1, 32, 16, 16]               0
#         ConvBlock-28           [-1, 32, 16, 16]               0
#            Conv2d-29           [-1, 16, 16, 16]             512
#         MaxPool2d-30             [-1, 16, 8, 8]               0
#   TransitionBlock-31             [-1, 16, 8, 8]               0
#            Conv2d-32             [-1, 16, 8, 8]           2,304
#              ReLU-33             [-1, 16, 8, 8]               0
#         GroupNorm-34             [-1, 16, 8, 8]              32
#           Dropout-35             [-1, 16, 8, 8]               0
#         ConvBlock-36             [-1, 16, 8, 8]               0
#            Conv2d-37             [-1, 32, 8, 8]           4,608
#              ReLU-38             [-1, 32, 8, 8]               0
#         GroupNorm-39             [-1, 32, 8, 8]              64
#           Dropout-40             [-1, 32, 8, 8]               0
#         ConvBlock-41             [-1, 32, 8, 8]               0
#            Conv2d-42             [-1, 32, 8, 8]           9,216
#              ReLU-43             [-1, 32, 8, 8]               0
#         GroupNorm-44             [-1, 32, 8, 8]              64
#           Dropout-45             [-1, 32, 8, 8]               0
#         ConvBlock-46             [-1, 32, 8, 8]               0
#         AvgPool2d-47             [-1, 32, 1, 1]               0
#            Conv2d-48             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 44,138
# Trainable params: 44,138
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.71
# Params size (MB): 0.17
# Estimated Total Size (MB): 3.89
# ----------------------------------------------------------------
# Loss=1.472733497619629 Batch_id=315 Accuracy=34.74:  81%|████████  | 316/391 [00:15<00:03, 20.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2e09ff6a7f86> in <cell line: 1>()
# ----> 1 model, test_loader = main(config)
#
# /content/s8-normalization/main.py in main(config, lr_scheduler)
#      14     scheduler = StepLR(optimizer, step_size=config['step_size'], gamma=0.1)
#      15     for epoch in range(config['epochs']):
# ---> 16         train(model, config['device'], train_loader, optimizer, epoch)
#      17         test(model, config['device'], test_loader)
#      18         if lr_scheduler == True:
#
# /content/s8-normalization/utils.py in train(model, device, train_loader, optimizer, epoch)
#      44
#      45         # Predict
# ---> 46         y_pred = model(data)
#      47
#      48         # Calculate loss
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/s8-normalization/models/model.py in forward(self, x)
#      83         x = self.conv4(x)
#      84         x = self.conv5(x)
# ---> 85         x = x + self.conv6(x)
#      86         x = self.conv7(x)
#      87         x = self.conv8(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/s8-normalization/models/model.py in forward(self, x)
#      33
#      34     def forward(self, x):
# ---> 35         return self.conv(x)
#      36
#      37 class TransitionBlock(nn.Module):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     285
#     286     def forward(self, input: Tensor) -> Tensor:
# --> 287         return F.group_norm(
#     288             input, self.num_groups, self.weight, self.bias, self.eps)
#     289
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in group_norm(input, num_groups, weight, bias, eps)
#    2559         raise RuntimeError(f"Expected at least 2 dimensions for input tensor but received {input.dim()}")
#    2560     _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
# -> 2561     return torch.group_norm(input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled)
#    2562
#    2563
#
# KeyboardInterrupt:
