# %%
# !git clone 'https://github.com/aakashvardhan/s8-normalization.git'
# Out:
# Cloning into 's8-normalization'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 115 (delta 53), reused 86 (delta 24), pack-reused 0
# Receiving objects: 100% (115/115), 1010.60 KiB | 14.44 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
import sys
sys.path.append('/content/s8-normalization')
sys.path.append('/content/s8-normalization/models')

# %%
from config import get_config
config = get_config()
from main import main
from torchvision import transforms

# %% [markdown]
# ### Modify Config File

# %%
config['norm'] = 'ln'


# Train Phase transformations
config['train_transforms'] = transforms.Compose([
                                      transforms.RandomAffine(degrees=20, translate=(0.1, 0.1), scale=(0.9, 1.1)),
                                      transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                      transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                       ])

# Test Phase transformations
config['test_transforms'] = transforms.Compose([
                                      #  transforms.Resize((28, 28)),
                                      #  transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                       ])

# %% [markdown]
# ### Train the Model

# %%
model, test_loader = main(config)
# Out:
# CUDA Available? True
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 47522441.50it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#               ReLU-2           [-1, 32, 32, 32]               0
#          GroupNorm-3           [-1, 32, 32, 32]              64
#            Dropout-4           [-1, 32, 32, 32]               0
#          ConvBlock-5           [-1, 32, 32, 32]               0
#             Conv2d-6           [-1, 32, 32, 32]           9,216
#               ReLU-7           [-1, 32, 32, 32]               0
#          GroupNorm-8           [-1, 32, 32, 32]              64
#            Dropout-9           [-1, 32, 32, 32]               0
#         ConvBlock-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]             512
#         MaxPool2d-12           [-1, 16, 16, 16]               0
#   TransitionBlock-13           [-1, 16, 16, 16]               0
#            Conv2d-14           [-1, 16, 16, 16]           2,304
#              ReLU-15           [-1, 16, 16, 16]               0
#         GroupNorm-16           [-1, 16, 16, 16]              32
#           Dropout-17           [-1, 16, 16, 16]               0
#         ConvBlock-18           [-1, 16, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           4,608
#              ReLU-20           [-1, 32, 16, 16]               0
#         GroupNorm-21           [-1, 32, 16, 16]              64
#           Dropout-22           [-1, 32, 16, 16]               0
#         ConvBlock-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 32, 16, 16]           9,216
#              ReLU-25           [-1, 32, 16, 16]               0
#         GroupNorm-26           [-1, 32, 16, 16]              64
#           Dropout-27           [-1, 32, 16, 16]               0
#         ConvBlock-28           [-1, 32, 16, 16]               0
#            Conv2d-29           [-1, 16, 16, 16]             512
#         MaxPool2d-30             [-1, 16, 8, 8]               0
#   TransitionBlock-31             [-1, 16, 8, 8]               0
#            Conv2d-32             [-1, 16, 8, 8]           2,304
#              ReLU-33             [-1, 16, 8, 8]               0
#         GroupNorm-34             [-1, 16, 8, 8]              32
#           Dropout-35             [-1, 16, 8, 8]               0
#         ConvBlock-36             [-1, 16, 8, 8]               0
#            Conv2d-37             [-1, 32, 8, 8]           4,608
#              ReLU-38             [-1, 32, 8, 8]               0
#         GroupNorm-39             [-1, 32, 8, 8]              64
#           Dropout-40             [-1, 32, 8, 8]               0
#         ConvBlock-41             [-1, 32, 8, 8]               0
#            Conv2d-42             [-1, 32, 8, 8]           9,216
#              ReLU-43             [-1, 32, 8, 8]               0
#         GroupNorm-44             [-1, 32, 8, 8]              64
#           Dropout-45             [-1, 32, 8, 8]               0
#         ConvBlock-46             [-1, 32, 8, 8]               0
#         AvgPool2d-47             [-1, 32, 1, 1]               0
#            Conv2d-48             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 44,138
# Trainable params: 44,138
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.71
# Params size (MB): 0.17
# Estimated Total Size (MB): 3.89
# ----------------------------------------------------------------
# EPOCH: 1
# Loss=1.685971975326538 Batch_id=390 Accuracy=30.94: 100%|██████████| 391/391 [00:56<00:00,  6.98it/s]
# Test set: Average loss: 1.6327, Accuracy: 3968/10000 (39.68%)
#
# EPOCH: 2
# Loss=1.5779430866241455 Batch_id=390 Accuracy=41.52: 100%|██████████| 391/391 [00:58<00:00,  6.70it/s]
# Test set: Average loss: 1.3808, Accuracy: 4957/10000 (49.57%)
#
# EPOCH: 3
# Loss=1.3894675970077515 Batch_id=390 Accuracy=47.98: 100%|██████████| 391/391 [00:57<00:00,  6.83it/s]
# Test set: Average loss: 1.3235, Accuracy: 5238/10000 (52.38%)
#
# EPOCH: 4
# Loss=1.46161949634552 Batch_id=390 Accuracy=51.51: 100%|██████████| 391/391 [00:56<00:00,  6.90it/s]
# Test set: Average loss: 1.2204, Accuracy: 5547/10000 (55.47%)
#
# EPOCH: 5
# Loss=1.14626145362854 Batch_id=390 Accuracy=54.72: 100%|██████████| 391/391 [00:58<00:00,  6.74it/s]
# Test set: Average loss: 1.1755, Accuracy: 5814/10000 (58.14%)
#
# EPOCH: 6
# Loss=1.3287138938903809 Batch_id=390 Accuracy=56.64: 100%|██████████| 391/391 [00:58<00:00,  6.65it/s]
# Test set: Average loss: 1.0569, Accuracy: 6187/10000 (61.87%)
#
# EPOCH: 7
# Loss=1.0904805660247803 Batch_id=390 Accuracy=58.49: 100%|██████████| 391/391 [00:57<00:00,  6.84it/s]
# Test set: Average loss: 1.0287, Accuracy: 6314/10000 (63.14%)
#
# EPOCH: 8
# Loss=1.088991641998291 Batch_id=390 Accuracy=59.84: 100%|██████████| 391/391 [00:57<00:00,  6.80it/s]
# Test set: Average loss: 1.0521, Accuracy: 6228/10000 (62.28%)
#
# EPOCH: 9
# Loss=1.2293976545333862 Batch_id=390 Accuracy=60.58: 100%|██████████| 391/391 [00:58<00:00,  6.72it/s]
# Test set: Average loss: 0.9789, Accuracy: 6480/10000 (64.80%)
#
# EPOCH: 10
# Loss=1.173709750175476 Batch_id=390 Accuracy=62.07: 100%|██████████| 391/391 [00:57<00:00,  6.84it/s]
# Test set: Average loss: 0.9225, Accuracy: 6691/10000 (66.91%)
#
# EPOCH: 11
# Loss=0.9050701856613159 Batch_id=390 Accuracy=62.35: 100%|██████████| 391/391 [00:56<00:00,  6.86it/s]
# Test set: Average loss: 0.9332, Accuracy: 6702/10000 (67.02%)
#
# EPOCH: 12
# Loss=1.0864434242248535 Batch_id=390 Accuracy=62.83: 100%|██████████| 391/391 [00:57<00:00,  6.82it/s]
# Test set: Average loss: 0.9839, Accuracy: 6536/10000 (65.36%)
#
# EPOCH: 13
# Loss=0.8303829431533813 Batch_id=390 Accuracy=63.81: 100%|██████████| 391/391 [00:56<00:00,  6.89it/s]
# Test set: Average loss: 0.9160, Accuracy: 6756/10000 (67.56%)
#
# EPOCH: 14
# Loss=1.052316665649414 Batch_id=390 Accuracy=64.28: 100%|██████████| 391/391 [00:56<00:00,  6.91it/s]
# Test set: Average loss: 0.8899, Accuracy: 6859/10000 (68.59%)
#
# EPOCH: 15
# Loss=1.1924607753753662 Batch_id=390 Accuracy=64.89: 100%|██████████| 391/391 [00:57<00:00,  6.80it/s]
# Test set: Average loss: 0.9098, Accuracy: 6777/10000 (67.77%)
#
# EPOCH: 16
# Loss=0.9720941781997681 Batch_id=390 Accuracy=65.05: 100%|██████████| 391/391 [00:55<00:00,  7.02it/s]
# Test set: Average loss: 0.8480, Accuracy: 6956/10000 (69.56%)
#
# EPOCH: 17
# Loss=0.8023234605789185 Batch_id=390 Accuracy=65.73: 100%|██████████| 391/391 [00:56<00:00,  6.98it/s]
# Test set: Average loss: 0.8471, Accuracy: 6980/10000 (69.80%)
#
# EPOCH: 18
# Loss=0.6571810245513916 Batch_id=390 Accuracy=66.15: 100%|██████████| 391/391 [00:57<00:00,  6.82it/s]
# Test set: Average loss: 0.8497, Accuracy: 6986/10000 (69.86%)
#
# EPOCH: 19
# Loss=1.0172982215881348 Batch_id=390 Accuracy=66.31: 100%|██████████| 391/391 [00:56<00:00,  6.98it/s]
# Test set: Average loss: 0.8455, Accuracy: 7021/10000 (70.21%)
#
# EPOCH: 20
# Loss=1.0581754446029663 Batch_id=390 Accuracy=66.76: 100%|██████████| 391/391 [00:55<00:00,  7.00it/s]
# Test set: Average loss: 0.8241, Accuracy: 7090/10000 (70.90%)

# %% [markdown]
# ### Plot Train/Test Accuracy

# %%
import matplotlib.pyplot as plt
from utils import plt_fig
plt_fig()

# %% [markdown]
# ### Show Misclassified Images (2x5)

# %%
from visualize import show_misclassified_images, plt_misclassified_images

# %%
misclass_imgs, misclass_targets, misclass_preds = show_misclassified_images(model, test_loader, config)
plt_misclassified_images(config, misclass_imgs, misclass_targets, misclass_preds)

# %%
len(misclass_imgs) # Incorrect
# Out:
# 2910
