# %%
# !git clone 'https://github.com/aakashvardhan/s8-normalization.git'
# Out:
# Cloning into 's8-normalization'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 146 (delta 71), reused 104 (delta 29), pack-reused 0
# Receiving objects: 100% (146/146), 1.55 MiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
import sys
sys.path.append('/content/s8-normalization')
sys.path.append('/content/s8-normalization/models')

# %%
from config import get_config
config = get_config()
from main import main
from torchvision import transforms

# %%
config['norm'] = 'gn'


# Train Phase transformations
config['train_transforms'] = transforms.Compose([
                                      transforms.RandomAffine(degrees=20, translate=(0.1, 0.1), scale=(0.9, 1.1)),
                                      transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                      transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                       ])

# Test Phase transformations
config['test_transforms'] = transforms.Compose([
                                      #  transforms.Resize((28, 28)),
                                      #  transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                       ])

# %%
model, test_loader = main(config)
# Out:
# CUDA Available? True
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 41904232.31it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#               ReLU-2           [-1, 32, 32, 32]               0
#          GroupNorm-3           [-1, 32, 32, 32]              64
#            Dropout-4           [-1, 32, 32, 32]               0
#          ConvBlock-5           [-1, 32, 32, 32]               0
#             Conv2d-6           [-1, 32, 32, 32]           9,216
#               ReLU-7           [-1, 32, 32, 32]               0
#          GroupNorm-8           [-1, 32, 32, 32]              64
#            Dropout-9           [-1, 32, 32, 32]               0
#         ConvBlock-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]             512
#         MaxPool2d-12           [-1, 16, 16, 16]               0
#   TransitionBlock-13           [-1, 16, 16, 16]               0
#            Conv2d-14           [-1, 16, 16, 16]           2,304
#              ReLU-15           [-1, 16, 16, 16]               0
#         GroupNorm-16           [-1, 16, 16, 16]              32
#           Dropout-17           [-1, 16, 16, 16]               0
#         ConvBlock-18           [-1, 16, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           4,608
#              ReLU-20           [-1, 32, 16, 16]               0
#         GroupNorm-21           [-1, 32, 16, 16]              64
#           Dropout-22           [-1, 32, 16, 16]               0
#         ConvBlock-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 32, 16, 16]           9,216
#              ReLU-25           [-1, 32, 16, 16]               0
#         GroupNorm-26           [-1, 32, 16, 16]              64
#           Dropout-27           [-1, 32, 16, 16]               0
#         ConvBlock-28           [-1, 32, 16, 16]               0
#            Conv2d-29           [-1, 16, 16, 16]             512
#         MaxPool2d-30             [-1, 16, 8, 8]               0
#   TransitionBlock-31             [-1, 16, 8, 8]               0
#            Conv2d-32             [-1, 16, 8, 8]           2,304
#              ReLU-33             [-1, 16, 8, 8]               0
#         GroupNorm-34             [-1, 16, 8, 8]              32
#           Dropout-35             [-1, 16, 8, 8]               0
#         ConvBlock-36             [-1, 16, 8, 8]               0
#            Conv2d-37             [-1, 32, 8, 8]           4,608
#              ReLU-38             [-1, 32, 8, 8]               0
#         GroupNorm-39             [-1, 32, 8, 8]              64
#           Dropout-40             [-1, 32, 8, 8]               0
#         ConvBlock-41             [-1, 32, 8, 8]               0
#            Conv2d-42             [-1, 32, 8, 8]           9,216
#              ReLU-43             [-1, 32, 8, 8]               0
#         GroupNorm-44             [-1, 32, 8, 8]              64
#           Dropout-45             [-1, 32, 8, 8]               0
#         ConvBlock-46             [-1, 32, 8, 8]               0
#         AvgPool2d-47             [-1, 32, 1, 1]               0
#            Conv2d-48             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 44,138
# Trainable params: 44,138
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.71
# Params size (MB): 0.17
# Estimated Total Size (MB): 3.89
# ----------------------------------------------------------------
# EPOCH: 1
# Loss=1.5534536838531494 Batch_id=390 Accuracy=29.82: 100%|██████████| 391/391 [01:01<00:00,  6.39it/s]
# Test set: Average loss: 1.5801, Accuracy: 4097/10000 (40.97%)
#
# EPOCH: 2
# Loss=1.5281018018722534 Batch_id=390 Accuracy=42.03: 100%|██████████| 391/391 [01:03<00:00,  6.17it/s]
# Test set: Average loss: 1.4073, Accuracy: 4891/10000 (48.91%)
#
# EPOCH: 3
# Loss=1.3343065977096558 Batch_id=390 Accuracy=48.38: 100%|██████████| 391/391 [01:02<00:00,  6.25it/s]
# Test set: Average loss: 1.3047, Accuracy: 5307/10000 (53.07%)
#
# EPOCH: 4
# Loss=1.4690215587615967 Batch_id=390 Accuracy=52.24: 100%|██████████| 391/391 [01:03<00:00,  6.15it/s]
# Test set: Average loss: 1.2407, Accuracy: 5534/10000 (55.34%)
#
# EPOCH: 5
# Loss=1.08296799659729 Batch_id=390 Accuracy=55.31: 100%|██████████| 391/391 [01:03<00:00,  6.20it/s]
# Test set: Average loss: 1.1153, Accuracy: 5970/10000 (59.70%)
#
# EPOCH: 6
# Loss=1.2993295192718506 Batch_id=390 Accuracy=57.36: 100%|██████████| 391/391 [01:02<00:00,  6.24it/s]
# Test set: Average loss: 1.0823, Accuracy: 6131/10000 (61.31%)
#
# EPOCH: 7
# Loss=1.1034798622131348 Batch_id=390 Accuracy=58.71: 100%|██████████| 391/391 [01:03<00:00,  6.16it/s]
# Test set: Average loss: 1.0343, Accuracy: 6308/10000 (63.08%)
#
# EPOCH: 8
# Loss=1.1431634426116943 Batch_id=390 Accuracy=60.12: 100%|██████████| 391/391 [01:02<00:00,  6.23it/s]
# Test set: Average loss: 1.0561, Accuracy: 6237/10000 (62.37%)
#
# EPOCH: 9
# Loss=1.2774863243103027 Batch_id=390 Accuracy=61.13: 100%|██████████| 391/391 [01:03<00:00,  6.19it/s]
# Test set: Average loss: 0.9715, Accuracy: 6524/10000 (65.24%)
#
# EPOCH: 10
# Loss=1.024027943611145 Batch_id=390 Accuracy=62.26: 100%|██████████| 391/391 [01:03<00:00,  6.18it/s]
# Test set: Average loss: 0.8987, Accuracy: 6833/10000 (68.33%)
#
# EPOCH: 11
# Loss=0.7952502965927124 Batch_id=390 Accuracy=62.90: 100%|██████████| 391/391 [01:03<00:00,  6.11it/s]
# Test set: Average loss: 0.9301, Accuracy: 6702/10000 (67.02%)
#
# EPOCH: 12
# Loss=1.1226338148117065 Batch_id=390 Accuracy=63.71: 100%|██████████| 391/391 [01:03<00:00,  6.11it/s]
# Test set: Average loss: 0.9216, Accuracy: 6707/10000 (67.07%)
#
# EPOCH: 13
# Loss=0.8741499781608582 Batch_id=390 Accuracy=64.43: 100%|██████████| 391/391 [01:03<00:00,  6.15it/s]
# Test set: Average loss: 0.9037, Accuracy: 6863/10000 (68.63%)
#
# EPOCH: 14
# Loss=0.8797330856323242 Batch_id=390 Accuracy=64.96: 100%|██████████| 391/391 [01:03<00:00,  6.20it/s]
# Test set: Average loss: 0.8649, Accuracy: 6977/10000 (69.77%)
#
# EPOCH: 15
# Loss=1.0328396558761597 Batch_id=390 Accuracy=65.29: 100%|██████████| 391/391 [01:03<00:00,  6.15it/s]
# Test set: Average loss: 0.8540, Accuracy: 6917/10000 (69.17%)
#
# EPOCH: 16
# Loss=0.9372323155403137 Batch_id=390 Accuracy=66.07: 100%|██████████| 391/391 [01:03<00:00,  6.17it/s]
# Test set: Average loss: 0.8233, Accuracy: 7107/10000 (71.07%)
#
# EPOCH: 17
# Loss=0.8834392428398132 Batch_id=390 Accuracy=66.47: 100%|██████████| 391/391 [01:03<00:00,  6.13it/s]
# Test set: Average loss: 0.8335, Accuracy: 7053/10000 (70.53%)
#
# EPOCH: 18
# Loss=0.7396939992904663 Batch_id=390 Accuracy=66.87: 100%|██████████| 391/391 [01:03<00:00,  6.13it/s]
# Test set: Average loss: 0.8189, Accuracy: 7106/10000 (71.06%)
#
# EPOCH: 19
# Loss=0.9720532298088074 Batch_id=390 Accuracy=67.13: 100%|██████████| 391/391 [01:03<00:00,  6.13it/s]
# Test set: Average loss: 0.8030, Accuracy: 7175/10000 (71.75%)
#
# EPOCH: 20
# Loss=1.0567971467971802 Batch_id=390 Accuracy=67.63: 100%|██████████| 391/391 [01:04<00:00,  6.10it/s]
# Test set: Average loss: 0.8015, Accuracy: 7261/10000 (72.61%)

# %%
import matplotlib.pyplot as plt
from utils import plt_fig
plt_fig()

# %%
from visualize import show_misclassified_images, plt_misclassified_images

# %%
misclass_imgs, misclass_targets, misclass_preds = show_misclassified_images(model, test_loader, config)
plt_misclassified_images(config, misclass_imgs, misclass_targets, misclass_preds)

# %%
len(misclass_imgs) # Incorrect
# Out:
# 2739
